# %% [markdown]
# # Traversing / Iterating over Lists
#
# ## To Access Data
#
# We can use a while-loop to move through a List's index locations, examining each piece of data stored there.
#
# A List's index values are just a sequence of numbers, starting at 0 and going up to one less than the total number of things in the List.
#
# ![image.png](attachment:be9f754b-bc74-45af-abb4-30646129881b.png)

# %%
#WARMUP - Create the list above. Write an input loop to populate that List with integer data entered by the uer.

# %%
# How do we use a loop to move through a sequence of numbers one by one?

# %% [markdown]
# **We can apply the same loop logic, over the sequence of index values for a List**
#
# To traverse a list with a loop we also need to know:
#
# 1) Where to start - the first index
# 2) Where to stop - the last index
#
# To know what the last index value is, we need to know the total number of things in the list. To do this we use `len()`:
#
# ```python
#
# data = [10, 5, 2, 1, 0, 4]
# length = len(data)
#
# ```

# %%
# Iterate over a List, displaying the data items one by one
