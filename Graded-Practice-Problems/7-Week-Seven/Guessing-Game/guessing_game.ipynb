# %% [markdown]
# # Guessing Game
#
# ## While-Loops: input terminated loops
#
# Write a game where the player tries to guess a number between 1 and 10. The hidden number is generated as a random integer between 1 and 10 in your program.
#
# <div style="background-color: #F8F8F8; border: 4px solid #30A5C7; padding: 10px; border-radius: 5px;">
#
# Hint: If this sounds a bit familiar, that's because it is. Refer back to the "Guess" program we wrote in Week Four.
#
# </div>
#
# * If the person's guess is incorrect, the program should tell them if their guess was **too high**, or **too low**. Then they should get a chance to guess again.
#
#
# * Once the player guesses the right answer, they win and the game ends.
#
#
# * They have exactly **3 total guesses**. If they run out of guesses before getting the correct number, they lose and the game ends.
#
# You do not need to write this game as a user-defined function if you do not want to, it may all be written in main().
#
#
# # Instructions
#
# ### 1) Define `main()`.
#
# Don't forget to call main() right after!
#
#
# ### 2) Generate the random, hidden number.
#
# Store this in a variable.
#
#
# ### 3) Welcome the player, and let the player take their first guess.
#
# Get their input value and convert it to an integer.
#
# ### 4) Write a while-loop that breaks if the person guesses correctly or if the person runs out of guesses (they have 3 total guesses).
#
# Within this loop the work that needs to be done is:
#
#   1) Evaluate the guess against the hidden number, does it match?
#   2) If it matches, ensure something changes so the loop condition becomes False and breaks.
#   3) If it doesn't match, display a message telling them why: was the guess too high, or too low?  The person should get to guess again as long as they still haven't exhausted their 3 total guesses.
#
# ### 5) Add a Main Program Menu
#
# Now write a Main Program Menu in `main()` that runs on a loop. Give the person three options:
#
# 1) See the game Instructions
# 2) Play the game
# 0) Quit
#
# Based off a value entered as input, one of these three options should be selected. Once an option is selected and runs, the main menu should be re-offered to the person using the program. The only time the main menu should NOT be re-offered, is if the person chooses option 0: to quit the program.
#
# In this case, the program should output the message "Quitting the program..." and then end.

# %%
# 👇👇 Start writing your code for the Guessing game program below this line 👇👇




# When finished, copy this code you wrote into the "guessing_game.py" file and finish filling out the Header Comments found there. Download and submit this .py file to the associated Canvas assignment
