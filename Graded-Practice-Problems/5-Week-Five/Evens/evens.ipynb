# %% [markdown]
# # Show Evens
#
# **While-Loops: conditional statements in the loop**
#
# The loop body code can be made up of any of the other code we've worked with so far. This includes conditional statements (if/elif/else).
#
# Write a function that takes one argument, a value for **n**. The functions job is to display as output, every whole integer **that is even** in a sequence from 1 to **n**. This function must use a **while-loop** to get the job done, and a **conditional statement** within the while-loops code body.
#
# Even-ness or Odd-ness of a number can be determined using the **mod-operator**:
#
# ```python
# a = 10
# b = 5
# result = a % b
# ```
#
# The mod operator `a % b` divides `b` into `a`, and returns the **remainder**:
#
# ```
# 9 % 2 returns 1 (four whole 2s can be pulled from 9, with a 1 leftover)
# 8 % 2 returns 0 (four whole 2s can be pulled from 8, with nothing leftover)
# 10 % 9 returns 1 (one whole 9 can be pulled from 10, with a 1 leftover)
# 13 % 5 returns 2 (two whole 5s can be pulled from 13, with a 3 leftover)
# 4 % 4 returns 0 (one whole 4 can be pulled from 4, with nothing leftover)
# 8 % 5 returns 3 (one whole 5 can be pulled from 8, with a 3 leftover)
#
# ...etc
# ```
#
# Modding number by 2 can be particularly helpful to this problem, see if you can figure out why:
#
# ```
# 9 % 2 returns 1
# 8 % 2 returns 0
# 7 % 2 returns 1
# 6 % 2 returns 0
# 5 % 2 returns 1
# 4 % 2 returns 0
# ...etc
# ```
#
#
# # Instructions
#
# ### 1) Write the **function definition header**
#
# Name your function: `show_evens`.
#
#
# ### 2) Write the **function body code**
# The **function body** code should use value passed into the **parameter** to perform the job of the function.
#
# This function does **NOT** need to **return** any value.
#
#
# ### 3) Use the function in main()
#
# Define a `main()` function.
#
# Prompt and gather the value for **n** as **input**, and store this information in a **variable**.
#
# Call the `show_evens` function you wrote, from `main()`, passing it the input value you just stored.
#
# ### 4) Output any results in main()
#
# The `show_evens` function will not return any values. So there is no need to do anything in `main()` after the function is called, except display a message that says: "Goodbye!".

# %%
# 👇👇 Start writing your code for the Show Evens program below this line 👇👇




# When finished, copy this code you wrote into the "sequence.py" file and finish filling out the Header Comments found there. Download and submit this .py file to the associated Canvas assignment.
