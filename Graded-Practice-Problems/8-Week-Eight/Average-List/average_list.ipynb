# %% [markdown]
# # Average of User Data in a List
#
# Once we have data in a List, we can **traverse / iterate** over that List to examine each piece of data one by one.
#
# We are going to write a program that creates a list of user-input data (as integers), then iterates over that List to calculate the average of the data.
#
# Don't worry about abstracting this program into functions just yet. Write everything in main().
#
# ## Instructions
#
# ### 1) Write a `main()` function.
#
# Don't forget to call main()!
#
# ### 2) In `main()`, create a List and fill it with user-input data.
#
# Create a new, empty List.
#
# Use an input-driven loop to let the person using the program enter one non-negative integer at a time as data. Every integer they enter gets appended to the List.
#
# To break the loop and discontinue entering data, the person using your program needs to enter the **terminating value** of -1. **Do not count the terminating value as data, and make sure it is not appended to the List.**
#
#
# ### 3) Process the Data: in `main()`, iterate over the List of Data and calculate the Average of all data
#
# Determine the length /size of the List using `len()`.
#
# Use the length to determine the value of the `last_index` in the List. This will always be one less than the length of the List.
#
# Write a while-loop that iterates over the List, starting at index 0 and working up to the last_index.
#
# At each index, access the value stored at that location in the List and use it to calculate the average of all data.
#
# ### 4) Handle for no data entered
#
# What if the user enters NO data? Write a conditional check that checks for this **before** any data processing happens. If the List is empty, output a message explaining that there is no data to process. Only process the data and calculate the average in the event the List is not empty.
#
# ## For Reference: Code for Calculating Average of Data entered in an input loop
#
# ```python
# def calculate_average():
#     average = 0
#     my_sum = 0
#     count = 0
#
#     number = int(input("Enter data one at a time, enter a -1 to stop: "))
#     while number != -1:
#         my_sum = my_sum + number #add the new data to the total
#         count = count + 1 #tally up the data
#
#         #get a new piece of data, it might be the terminating value of -1
#         number = int(input("Enter data one at a time, enter a -1 to stop: "))
#
#     #After the loop breaks, we have all the info we need to calculate the average
#     #but only if we got data entered, if there was no data entered
#     if my_sum != 0 and count != 0:
#         average = my_sum / count
#     else:
#         average = -1 #error flag, no data entered
#
#     return average
#
#
# def main():
#     result = calculate_average()
#     if result > 0:
#         print(f"The average of all data entered is: {result}")
#     else:
#         print("No data was entered.")
#
#
# main()
# ```

# %%
# 👇👇 Start writing your code for the Average List program below this line 👇👇




# When finished, copy this code you wrote into the "guessing_game.py" file and finish filling out the Header Comments found there. Download and submit this .py file to the associated Canvas assignment
