# %%
# 👇👇 Start writing your code for the Step Counter program below this line 👇👇




# When finished, copy this code you wrote into the "steps.py" file and finish filling out the Header Comments found there. Download and submit this .py file to the associated Canvas assignment

# %% [markdown]
# # EXTRA CREDIT: STEP COUNTER PROGRAM
#
# This program will start by gathering input data from the person using the program.  The data will be integer values, representing the total number of steps they took each day.
#
# As each data value is given as input, it should be stored inside a **list** using the `append()` function.
#
# This List should only end up containing exactly **7** pieces of data, one for each day of the week:
#
# Monday's steps live in index 0
# Tuesdays steps live at index 1
# Wednesdays steps live at index 2
# etc...
#
# After the data is gathered, write a Main Program Menu that lets the person using your program choose between three options, or enter some value to quit the program:
#
# 1) See all steps
# 2) View steps for a particular day
# 3) Update steps for a particular day
# 4) Quit
#
#
# #### Menu Option 1: See all steps
# ___
#
# If the person chooses **option 1** to see all steps, you're program should output every item in the List **one at a time using a while-loop to iterate over the List**. Do NOT simply print the list.
#
# #### Menu Option 2: View steps for a particular day
# ___
#
# If the person chooses **option 2** to view steps for a particular day, they should be prompted to enter an integer to specify which day:
#
# Choose `0` to see Monday's steps
# Choose `1` to see Tuesday's steps
# Choose `2` to see Wednesday's steps
# Choose `3` to see Thursday's steps
# Choose `4` to see Friday's steps
# Choose `5` to see Saturday's steps
# Choose `6` to see Sunday's steps
#
# After the person makes their selection, they should see output displaying the number of steps they took on the day selected.
#
# #### Menu Option 3: Update steps for a particular day
# ___
#
# If the person chooses **option 3** to update steps for a particular day, they should be prompted to enter an integer to specify which day:
#
# Choose `0` to update Monday's steps
# Choose `1` to update Tuesday's steps
# Choose `2` to update Wednesday's steps
# Choose `3` to update Thursday's steps
# Choose `4` to update Friday's steps
# Choose `5` to update Saturday's steps
# Choose `6` to update Sunday's steps
#
# After the person makes their selection, they should see output displaying the current number of steps they entered for that day, and also be given the opportunity to enter a NEW value for that day. Once they enter that new value and hit enter, the old value in the list will overwritten with the new one.
#
# #### Menu Option 4: Quit
# ___
# Program ends.
#
# # Instructions
#
# ### 1) Define a `main()` function.
#
# ### 2) Create an empty list, call it `weeks_steps`
#
# ### 3) Get the data, put it in the list
#
# Write an input driven while-loop to take in exactly **seven** values of step-count data and stores each inside the `weeks_steps` list
#
# You will want to use the `append()` function.
#
# <div style="background-color: #F8F8F8; border: 4px solid #30D5C8; padding: 10px; border-radius: 5px;">
#
# # BONUS OPTION #1
#
# Can you adapt this so each time the person is prompted to enter data, the prompt correctly asks for the right day of the week?
#
# **Example**:
# ```txt
# Hello enter your steps data for the week!
#
# Enter Monday's steps: 7890
# Enter Tuesday's steps: 1005
# Enter Wednesday's steps: 8956
# Enter Thursday's steps: 4567
# Enter Friday's steps: 11345
# Enter Saturday's steps: 12999
# Enter Sunday's steps: 6733
#
# Thank you!
# ```
# </div>
#
# ### 4) Write the Main Program Menu
#
# Implement a program menu that only starts being offered AFTER the data has been gathered. It lets the user choose whether they'd like to:
#
# 1) See all steps
# 2) View steps for a particular day
# 3) Update steps for a particular day
# 4) Quit
#
#
# The Main Program Menu should be re-offered after each selection until the user chooses to quit. Before the program terminates, display a message that says: "Goodbye!".
#
# ### 5) Write the function to display all steps, one by one
#
# This functions job is to take in some List full of step data as an argument, and output every item in that List **one at a time using a while-loop to iterate over the List**. Do NOT simply print the list.
#
# Call this function from the right place in the Main Program Menu (where the user chooses Option 1).
#
#
# **Correct output for "see all steps" option:**
# ```txt
# Menu
# 1) See all steps
# 1. 2) View steps for a particular day
# 3) Update steps for a particular day
# 0) Quit
#
# Choose a menu option or 0 to quit: 1
#
# 7890
# 1005
# 8956
# 4567
# 11345
# 12999
# 6733
# ```
#
# **Incorrect output for "see all steps":**
#
# ```txt
#
# Menu
# 1) See all steps
# 2) View steps for a particular day
# 3) Update steps for a particular day
# 0) Quit
#
# Choose a menu option or 0 to quit: 1
#
# [7890, 1005, 8956, 4567, 11345, 12999, 6733]
# ```
#
# <div style="background-color: #F8F8F8; border: 4px solid #30D5C8; padding: 10px; border-radius: 5px;">
#
# # BONUS OPTION #2
#
# Can you alter this function so it displays the correct days label next to each step-count data displayed?
#
# ```txt
#
# Menu
# 1) See all steps
# 2) View steps for a particular day
# 3) Update steps for a particular day
# 0) Quit
#
# Choose a menu option or 0 to quit: 1
#
# Monday: 7890
# Tuesday: 1005
# Wednesday: 8956
# Thursday: 4567
# Friday: 11345
# Saturday: 12999
# Sunday: 6733
# ```
#
# </div>
#
# ### 6) Write the function to display steps for a particular day
#
# This functions job is to take in some list full of step data as an argument, get a selection from the person using the program, and display the requested days steps.
#
# Call this function from the right place in the Main Program Menu (where the user chooses Option 2).
#
# Consider that your `weeks_steps` list has exactly seven items, so it has exactly seven index values. Each index value maps to a day of the week:
#
# `0` represents Monday
# `1` represents Tuesday
# `2` represents Wednesday
# `3` represents Thursday
# `4` represents Friday
# `5` represents Saturday
# `6` represents Sunday
#
# Ask the person using the program to enter an integer between 0 and 6, describe the meaning of each of these integers in an output message prompt.
#
# Use that integer value to access the `weeks_steps` list at the correct index and display the steps value found there.
#
# <div style="background-color: #F8F8F8; border: 4px solid #30D5C8; padding: 10px; border-radius: 5px;">
#
# ## BONUS OPTION #3
#
# Can you adapt this so the person using your program gets to type in the **actual name of the day of the week** as text? Then your program converts this text name into the correct corresponding index integer?
#
# **Example:** if they type `Tuesday` your program converts this to the integer `1`, accesses your `weekly_steps` List at index `1`, and displays back the number of steps found there.
#
#
# </div>
#
# <div style="background-color: #F8F8F8; border: 4px solid #30D5C8; padding: 10px; border-radius: 5px;">
#
# ## BONUS OPTION #4
#
# Can you adapt this so that this View steps for a particular day-steps feature runs on a loop? Where the person only returns back to the Main Program Menu if they choose to quit this particular feature?
#
# </div>
#
# ### 6) Write the feature to update steps for a particular day
#
# This functions job is to take in some list full of step data as an argument, get a selection from the person using the program, and update the selected days steps to a new value entered by the user.
#
# Call this function from the right place in the Main Program Menu (where the user chooses Option 3).
#
# Consider that your `weeks_steps` list has exactly seven items, so it has exactly seven index values. Each index value maps to a day of the week:
#
# `0` represents Monday
# `1` represents Tuesday
# `2` represents Wednesday
# `3` represents Thursday
# `4` represents Friday
# `5` represents Saturday
# `6` represents Sunday
#
# Ask the person using the program to enter an integer between 0 and 6, describe the meaning of each of these integers in an output message prompt.
#
# Use that integer value to access the `weeks_steps` list at the correct index. Display the current value stored there, and prompt the person using your program to enter a NEW value. Once they enter a new value, overwrite the old value at this index with the new input value.
#
#
# # Example Finished Program Output
# ___
# ```txt
#
# Hello enter your steps data for the week!
#
# Enter steps: 7890
# Enter steps: 1005
# Enter steps: 8956
# Enter steps: 4567
# Enter steps: 11345
# Enter steps: 12999
# Enter steps: 6733
#
# Thank you!
#
# Menu
# 1) See all steps
# 2) View steps for a particular day
# 3) Update steps for a particular day
# 0) Quit
#
# Choose a menu option or 0 to quit: 1
#
# 7890
# 1005
# 8956
# 4567
# 11345
# 12999
# 6733
#
# Menu
# 1) See all steps
# 2) View steps for a particular day
# 3) Update steps for a particular day
# 0) Quit
#
# Choose a menu option or 0 to quit: 2
#
# Daily Menu
# Choose `0` to see Monday's steps
# Choose `1` to see Tuesday's steps
# Choose `2` to see Wednesday's steps
# Choose `3` to see Thursday's steps
# Choose `4` to see Friday's steps
# Choose `5` to see Saturday's steps
# Choose `6` to see Sunday's steps
#
# Enter your choice: 6
#
# On Sunday you took 6733 steps this week.
#
# Menu
# 1) See all steps
# 2) View steps for a particular day
# 3) Update steps for a particular day
# 0) Quit
#
# Choose a menu option or 0 to quit: 3
#
# Daily Menu
# Choose `0` to update Monday's steps
# Choose `1` to update Tuesday's steps
# Choose `2` to update Wednesday's steps
# Choose `3` to update Thursday's steps
# Choose `4` to update Friday's steps
# Choose `5` to update Saturday's steps
# Choose `6` to update Sunday's steps
#
# Enter your choice: 0
#
# On Monday you took 7890 steps this week.
#
# Please enter the new steps value for Monday:  8000
#
# You've updated your weekly steps to: [8000, 1005, 8956, 4567, 11345, 12999, 6733].
#
# Menu
# 1) See all steps
# 2) View steps for a particular day
# 3) Update steps for a particular day
# 0) Quit
#
# Choose a menu option or 0 to quit: 2
#
# Daily Menu
# Choose `0` to see Monday's steps
# Choose `1` to see Tuesday's steps
# Choose `2` to see Wednesday's steps
# Choose `3` to see Thursday's steps
# Choose `4` to see Friday's steps
# Choose `5` to see Saturday's steps
# Choose `6` to see Sunday's steps
#
# Enter your choice: 3
#
# On Wednesday you took 8956 steps this week.
#
# Menu
# 1) See all steps
# 2) View steps for a particular day
# 3) Update steps for a particular day
# 0) Quit
#
# Choose a menu option or 0 to quit: 0
#
# Goodbye!
# ```
#
#
# # Example Output with ALL four BONUS OPTIONS implemented:
#
# *Note:* the output for the option to update a days steps will behave the same as in the previous example output as there are no bonus options to be added to that feature.
#
# ```txt
#
# Hello enter your steps data for the week!
#
# Enter Monday's steps: 7890
# Enter Tuesday's steps: 1005
# Enter Wednesday's steps:8956
# Enter Thursday's steps: 4567
# Enter Friday's steps: 11345
# Enter Saturday's steps: 12999
# Enter Sunday's steps: 6733
#
# Thank you!
#
# Menu
# 1) See all steps
# 2) View steps for a particular day
# 3) Update steps for a particular day
# 0) Quit
#
# Choose a menu option or 0 to quit: 1
#
# Monday: 7890
# Tuesday: 1005
# Wednesday: 8956
# Thursday: 4567
# Friday: 11345
# Saturday: 12999
# Sunday: 6733
#
# Menu
# 1) See all steps
# 2) View steps for a particular day
# 3) Update steps for a particular day
# 0) Quit
#
# Choose a menu option or 0 to quit: 2
#
# Daily Menu
# Type "Monday" to see Monday's steps
# Type "Tuesday" to see Tuesday's steps
# Type "Wednesday" to see Wednesday's steps
# Type "Thursday" to see Thursday's steps
# Type "Friday" to see Friday's steps
# Type "Saturday" to see Saturday's steps
# Type "Sunday" to see Sunday's steps
# Type "Quit" to return to the Main Menu
#
# Enter your choice: Sunday
#
# On Sunday you took 6733 steps this week.
#
# Daily Menu
# Type "Monday" to see Monday's steps
# Type "Tuesday" to see Tuesday's steps
# Type "Wednesday" to see Wednesday's steps
# Type "Thursday" to see Thursday's steps
# Type "Friday" to see Friday's steps
# Type "Saturday" to see Saturday's steps
# Type "Sunday" to see Sunday's steps
# Type "Quit" to return to the Main Menu
#
#
# Enter your choice: Wednesday
#
# On Wednesday you took 8956 steps this week.
#
# Daily Menu
# Type "Monday" to see Monday's steps
# Type "Tuesday" to see Tuesday's steps
# Type "Wednesday" to see Wednesday's steps
# Type "Thursday" to see Thursday's steps
# Type "Friday" to see Friday's steps
# Type "Saturday" to see Saturday's steps
# Type "Sunday" to see Sunday's steps
# Type "Quit" to return to the Main Menu
#
# Enter your choice: -1
#
# Menu
# 1) See all steps
# 2) View steps for a particular day
# 3) Update steps for a particular day
# 0) Quit
#
# Choose a menu option or 0 to quit: 0
#
# Goodbye!
# ```
